# %% [markdown]
# **Author:** Jozef Hanč, Martina Hančová <br>
# [Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN) *P. J. Šafárik University in Košice, Slovakia* <br>
# email: [jozef.hanc@upjs.sk](mailto:jozef.hanc@upjs.sk)
# ****
#
# # <font color=brown>Sage implementation U(a,b,z)</font>
#
# ### Tricomi's confluent hypergeometric function U $-$ SageMath 8.3

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
a1, b1, a2, b2 =  1/2, 1, 17/2, 93
plot(hypergeometric_U(1-a1, 2-a1-a2, x*(b1+b2)), x, 0, 5, ymin=0, ymax=0.16, frame=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # <font color=brown>Mathematica implementation U(a,b,z)</font>
#
# <img src= 'https://www.dropbox.com/s/o145c6sbw2sqc5v/Mathematica11.png?raw=1' width='650' align ='left'>
